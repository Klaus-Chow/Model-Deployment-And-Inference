# %%
import torch

# %%
model=torch.load("./model/crnn_model.pt")

# %%
model.eval()
# Out:
# CRNNSmallNoLSTM(
#   (cnn): MobileNetV3(
#     (conv1): RepVGGBlock(
#       (nonlinearity): hswish()
#       (se): Identity()
#       (rbr_reparam): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (blocks): Sequential(
#       (0): ResidualUnit(
#         (expand_conv): ConvBNLayer(
#           (conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act_fun): ReLU()
#         )
#         (bottleneck_conv): RepVGGBlock(
#           (nonlinearity): ReLU()
#           (se): Identity()
#           (rbr_reparam): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#         )
#         (linear_conv): ConvBNLayer(
#           (conv): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
# ...

# %%
for name, param in model.named_parameters():
    print(name, '      ', param)
    break
# Out:
# cnn.conv1.rbr_reparam.weight        Parameter containing:
# tensor([[[[-9.3527e-02,  2.2050e-01,  1.9816e-01],
#           [ 3.3417e-01,  1.4946e+00, -3.5577e+00],
#           [ 5.8454e-02,  3.7799e-02,  2.3395e+00]],
#
#          [[-1.9154e-01,  1.2118e-01,  2.8744e-02],
#           [ 2.0788e-01,  1.7554e-01, -3.6738e+00],
#           [ 3.3939e-02, -9.0552e-02,  2.1861e+00]],
#
#          [[-5.7961e-02,  2.7493e-01,  1.6994e-01],
#           [ 4.1300e-01, -9.5534e-02, -3.4607e+00],
#           [ 2.1296e-01,  9.0130e-02,  2.4249e+00]]],
#
#
#         [[[-1.5273e-03, -2.2898e-03, -4.6361e-05],
#           [-3.6103e-03,  1.1281e+00, -1.9691e-03],
#           [-3.3454e-03,  7.0631e-04, -4.9223e-05]],
#
#          [[-1.5663e-03, -2.3990e-03, -9.5082e-05],
#           [-3.6344e-03,  1.4042e+00, -1.9589e-03],
#           [-3.3598e-03,  6.9165e-04, -4.7693e-05]],
#
#          [[-1.8112e-03, -2.5794e-03, -2.2168e-04],
#           [-3.7084e-03,  1.8448e-01, -1.9901e-03],
# ...
